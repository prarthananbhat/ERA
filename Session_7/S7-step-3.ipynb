# %% [markdown]
# CODE BLOCK: 1

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import sys
sys.path.insert(0,"/content/drive/MyDrive/ERA/Session_7")

# %%
from utils import plot_samples, plot_accuracy_metrics
from models import *

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %% [markdown]
# CODE BLOCK: 2

# %%
# CUDA?
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# CUDA Available? True
# cuda

# %% [markdown]
# CODE BLOCK: 3

# %%
# Train data transformations
train_transforms = transforms.Compose([
    # transforms.RandomApply([transforms.CenterCrop(22), ], p=0.1),
    # transforms.Resize((28, 28)),
    # transforms.RandomRotation((-15., 15.), fill=0),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
    ])

# Test data transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
    ])

# %% [markdown]
# CODE BLOCK: 4

# %%
train_data = datasets.MNIST('../data', train=True, download=True, transform=train_transforms)
test_data = datasets.MNIST('../data', train=False, download=True, transform=test_transforms)
# train_data = datasets.MNIST('../data', train=True, download=True)
# test_data = datasets.MNIST('../data', train=False, download=True)

# %% [markdown]
# CODE BLOCK: 5

# %%
batch_size = 512

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 2, 'pin_memory': True}

test_loader = torch.utils.data.DataLoader(train_data, **kwargs)
train_loader = torch.utils.data.DataLoader(train_data, **kwargs)

# %% [markdown]
# CODE BLOCK: 6

# %%
import matplotlib.pyplot as plt

batch_data, batch_label = next(iter(train_loader))
plot_samples(batch_data,batch_label)

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = model_3().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#               ReLU-2           [-1, 16, 26, 26]               0
#        BatchNorm2d-3           [-1, 16, 26, 26]              32
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#               ReLU-5           [-1, 16, 24, 24]               0
#        BatchNorm2d-6           [-1, 16, 24, 24]              32
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8            [-1, 8, 12, 12]             136
#            Dropout-9            [-1, 8, 12, 12]               0
#            Conv2d-10           [-1, 16, 10, 10]           1,168
#              ReLU-11           [-1, 16, 10, 10]               0
#       BatchNorm2d-12           [-1, 16, 10, 10]              32
#            Conv2d-13             [-1, 16, 8, 8]           2,320
#              ReLU-14             [-1, 16, 8, 8]               0
#       BatchNorm2d-15             [-1, 16, 8, 8]              32
#            Conv2d-16             [-1, 10, 8, 8]             170
#         AvgPool2d-17             [-1, 10, 1, 1]               0
# ================================================================
# Total params: 6,402
# Trainable params: 6,402
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.56
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.59
# ----------------------------------------------------------------

# %% [markdown]
# CODE BLOCK: 8

# %%
# Data to plot accuracy and loss graphs
train_losses = []
test_losses = []
train_acc = []
test_acc = []

test_incorrect_pred = {'images': [], 'ground_truths': [], 'predicted_vals': []}

# %% [markdown]
# CODE BLOCK: 9

# %%
from tqdm import tqdm

def GetCorrectPredCount(pPrediction, pLabels):
  return pPrediction.argmax(dim=1).eq(pLabels).sum().item()

def train(model, device, train_loader, optimizer):
  model.train()
  pbar = tqdm(train_loader)

  train_loss = 0
  correct = 0
  processed = 0

  for batch_idx, (data, target) in enumerate(pbar):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()

    # Predict
    pred = model(data)

    # Calculate loss
    loss = F.nll_loss(pred, target)
    train_loss+=loss.item()

    # Backpropagation
    loss.backward()
    optimizer.step()

    correct += GetCorrectPredCount(pred, target)
    processed += len(data)

    pbar.set_description(desc= f'Train: Loss={loss.item():0.4f} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')

  train_acc.append(100*correct/processed)
  train_losses.append(train_loss/len(train_loader))

def test(model, device, test_loader):
    model.eval()

    test_loss = 0
    correct = 0

    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)

            output = model(data)
            # test_loss += criterion(output, target, reduction='sum').item()  # sum up batch loss
            # loss_fn = nn.CrossEntropyLoss(reduction='sum')
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss

            correct += GetCorrectPredCount(output, target)


    test_loss /= len(test_loader.dataset)
    test_acc.append(100. * correct / len(test_loader.dataset))
    test_losses.append(test_loss)

    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# CODE BLOCK: 10

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1, verbose=True)
# New Line
# criterion = nn.CrossEntropyLoss()
num_epochs = 15

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer)
  test(model, device, test_loader)
  # scheduler.step()
# Out:
# Epoch 1
# Train: Loss=0.9959 Batch_id=117 Accuracy=47.96: 100%|██████████| 118/118 [00:14<00:00,  8.17it/s]
# Test set: Average loss: 1.0330, Accuracy: 46507/60000 (77.51%)
#
# Epoch 2
# Train: Loss=0.4001 Batch_id=117 Accuracy=87.54: 100%|██████████| 118/118 [00:14<00:00,  8.22it/s]
# Test set: Average loss: 0.3928, Accuracy: 55535/60000 (92.56%)
#
# Epoch 3
# Train: Loss=0.2219 Batch_id=117 Accuracy=94.22: 100%|██████████| 118/118 [00:14<00:00,  8.30it/s]
# Test set: Average loss: 0.2163, Accuracy: 57402/60000 (95.67%)
#
# Epoch 4
# Train: Loss=0.1855 Batch_id=117 Accuracy=96.03: 100%|██████████| 118/118 [00:15<00:00,  7.39it/s]
# Test set: Average loss: 0.1482, Accuracy: 58128/60000 (96.88%)
#
# Epoch 5
# Train: Loss=0.1762 Batch_id=117 Accuracy=96.84: 100%|██████████| 118/118 [00:14<00:00,  8.14it/s]
# Test set: Average loss: 0.1396, Accuracy: 57975/60000 (96.62%)
#
# Epoch 6
# Train: Loss=0.1463 Batch_id=117 Accuracy=97.34: 100%|██████████| 118/118 [00:14<00:00,  8.09it/s]
# Test set: Average loss: 0.1194, Accuracy: 58253/60000 (97.09%)
#
# Epoch 7
# Train: Loss=0.1098 Batch_id=117 Accuracy=97.65: 100%|██████████| 118/118 [00:14<00:00,  8.13it/s]
# Test set: Average loss: 0.0868, Accuracy: 58738/60000 (97.90%)
#
# Epoch 8
# Train: Loss=0.1394 Batch_id=117 Accuracy=97.84: 100%|██████████| 118/118 [00:14<00:00,  8.11it/s]
# Test set: Average loss: 0.0791, Accuracy: 58872/60000 (98.12%)
#
# Epoch 9
# Train: Loss=0.1553 Batch_id=117 Accuracy=97.94: 100%|██████████| 118/118 [00:14<00:00,  8.05it/s]
# Test set: Average loss: 0.0773, Accuracy: 58822/60000 (98.04%)
#
# Epoch 10
# Train: Loss=0.0554 Batch_id=117 Accuracy=98.08: 100%|██████████| 118/118 [00:14<00:00,  8.10it/s]
# Test set: Average loss: 0.0720, Accuracy: 58904/60000 (98.17%)
#
# Epoch 11
# Train: Loss=0.0996 Batch_id=117 Accuracy=98.28: 100%|██████████| 118/118 [00:14<00:00,  8.15it/s]
# Test set: Average loss: 0.0691, Accuracy: 58957/60000 (98.26%)
#
# Epoch 12
# Train: Loss=0.0617 Batch_id=117 Accuracy=98.28: 100%|██████████| 118/118 [00:14<00:00,  8.14it/s]
# Test set: Average loss: 0.0578, Accuracy: 59084/60000 (98.47%)
#
# Epoch 13
# Train: Loss=0.0442 Batch_id=117 Accuracy=98.38: 100%|██████████| 118/118 [00:14<00:00,  8.19it/s]
# Test set: Average loss: 0.0525, Accuracy: 59161/60000 (98.60%)
#
# Epoch 14
# Train: Loss=0.0294 Batch_id=117 Accuracy=98.48: 100%|██████████| 118/118 [00:14<00:00,  8.01it/s]
# Test set: Average loss: 0.0511, Accuracy: 59214/60000 (98.69%)
#
# Epoch 15
# Train: Loss=0.0674 Batch_id=117 Accuracy=98.52: 100%|██████████| 118/118 [00:14<00:00,  8.15it/s]
# Test set: Average loss: 0.0561, Accuracy: 59112/60000 (98.52%)

# %% [markdown]
# CODE BLOCK: 11

# %%
plot_accuracy_metrics(train_losses,train_acc,test_losses,test_acc)
